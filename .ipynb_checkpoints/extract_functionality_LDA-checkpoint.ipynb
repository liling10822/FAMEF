# %%
import os
import pandas as pd
import re
from string import punctuation

# %%
import gensim
from gensim.utils import simple_preprocess

# %%
from nltk.stem import WordNetLemmatizer, SnowballStemmer

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_md')

# %%
import markdown
from bs4 import BeautifulSoup

# %%
description_file './training_corpus//'

# %%
df = pd.DataFrame(columns=['file_name','raw_text'])

# %% [markdown]
# # Reading readme files and preprocessing it

# %%
files = os.listdir(source_dir)

# %%
files.remove('.DS_Store')

# %%
for file in files:
    full_path= os.path.join(source_dir+file)
   
    with open (full_path,'r',errors='ignore') as f:
        html = markdown.markdown(open(full_path).read())
        text = "".join(BeautifulSoup(html).findAll(text=True))
        df.loc[len(df)] = [file,text]

# %%
len(df)
# Out:
# 113

# %%
df['raw_text'][0][:500]
# Out:
# 'GPRPy\nOpen-source Ground Penetrating Radar processing and visualization software.\n\n\nSimplemost installation\nIn the following instructions, if you use Windows, use the comands python and pip. If you use Mac or Linux, use the commands python3 and pip3 instead.\n1) Download the GPRPy software from \n   https://github.com/NSGeophysics/GPRPy/archive/master.zip. \n   Save the file somewhere on your computer and extract the zip folder. \n   As an alternative, you can install git from https://git-scm.com/, '

# %%
df.head()
# Out:
#                file_name                                           raw_text
# 0        GPRPy-README.md  GPRPy\nOpen-source Ground Penetrating Radar pr...
# 1   SRN-Deblur-README.md  Scale-recurrent Network for Deep Image Deblurr...
# 2  sentinelsat-README.md  sentinelsat\n.. image:: https://badge.fury.io/...
# 3          RDN-README.md  Residual Dense Network for Image Super-Resolut...
# 4        Fiona-README.md  =====\nFiona\n=====\nFiona is OGR's neat and n...

# %%
df['raw_text'] = df['raw_text'].map(lambda x: re.sub(r'[\.\?\!,=]','',x))
# remove digits                                      
regex = re.compile(r'\d*')
df['raw_text'] = df['raw_text'].map(lambda x: re.sub(regex,'',x))
# convert to lower case
df['raw_text'] = df['raw_text'].map(lambda x: x.lower())

# %%
df.head()
# Out:
#                file_name                                           raw_text
# 0        GPRPy-README.md  gprpy\nopen-source ground penetrating radar pr...
# 1   SRN-Deblur-README.md  scale-recurrent network for deep image deblurr...
# 2  sentinelsat-README.md  sentinelsat\n image:: https://badgefuryio/py/s...
# 3          RDN-README.md  residual dense network for image super-resolut...
# 4        Fiona-README.md  \nfiona\n\nfiona is ogr's neat and nimble api ...

# %%
def sent_to_words(sentences):
    for sent in sentences:
        yield(simple_preprocess(str(sent)))
# def preprocess(doc):
#     texts = []
#     for sent in doc:
#         text
        
#     tokens_without_stopwords = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
#     #lemmatize tokens
#     texts_out = []
#     for sent in texts:
        
        
#         doc = nlp(" ".join(sent)) 


#         texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
#     return texts_out

# %%
stemmer = SnowballStemmer('english')
original_words = ['caresses', 'flies', 'dies', 'mules', 'denied','died', 'agreed', 'owned', 
           'humbled', 'sized','meeting', 'stating', 'siezing', 'itemization','sensational', 
           'traditional', 'reference', 'colonizer','plotted']
singles = [stemmer.stem(WordNetLemmatizer().lemmatize(plural)) for plural in original_words]
pd.DataFrame(data = {'original word': original_words, 'stemmed': singles})
# Out:
#    original word stemmed
# 0       caresses  caress
# 1          flies     fli
# 2           dies      dy
# 3          mules    mule
# 4         denied    deni
# 5           died     die
# 6         agreed    agre
# 7          owned     own
# 8        humbled   humbl
# 9          sized    size
# 10       meeting    meet
# 11       stating   state
# 12       siezing    siez
# 13   itemization    item
# 14   sensational  sensat
# 15   traditional  tradit
# 16     reference   refer
# 17     colonizer   colon
# 18       plotted    plot

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
stop_words_new =['code','file','text','use','http','https','install','using','import','python','instal','example','documentation']

# %%
stop_words.extend(stop_words_new)

# %%
def lemmatize_stemming(word):
     stemmer = nltk.stem.SnowballStemmer('english')
     return stemmer.stem(word)
        
    
   
    
def preprocess(text):
    result = []
    for token in simple_preprocess(text):
        if token not in stop_words and len(token) > 3:
            token =lemmatize_stemming(token)
            
            result.append(token)
                
    return result

# %%
processed_docs =df['raw_text'].map(preprocess)

# %%
bigram = gensim.models.Phrases(data_to_words, min_count=5, threshold=100) 
trigram = gensim.models.Phrases(bigram[data_to_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %%
def remove_stopwords(texts):
    
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    
    texts_out = []
    for sent in texts:
        
        
        doc = nlp(" ".join(sent)) 


        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
words_lemmatized[60]
# Out:
# ['paper',
#  'full',
#  'pytorch',
#  'implementation',
#  'high',
#  'resolution',
#  'photorealistic',
#  'video',
#  'video',
#  'translation',
#  'use',
#  'turn',
#  'semantic',
#  'label',
#  'map',
#  'photo',
#  'realistic',
#  'video',
#  'synthesize',
#  'people',
#  'talk',
#  'edge',
#  'map',
#  'generate',
#  'human',
#  'motion',
#  'pose',
#  'core',
#  'video',
#  'video',
#  'translation',
#  'image',
#  'image',
#  'translation',
#  'work',
#  'space',
#  'find',
#  'pixpixhd',
#  'spade',
#  'video',
#  'video',
#  'synthesis',
#  'neural',
#  'information',
#  'processing',
#  'system',
#  'neurip',
#  'video',
#  'video',
#  'translation',
#  'label',
#  'streetview',
#  'result',
#  'edge',
#  'face',
#  'result',
#  'pose',
#  'body',
#  'result',
#  'frame',
#  'prediction',
#  'result',
#  'get',
#  'start',
#  'library',
#  'dominate',
#  'request',
#  'bash',
#  'dominate',
#  'request',
#  'plan',
#  'train',
#  'face',
#  'dataset',
#  'bash',
# ...

# %%
import gensim.corpora as corpora

# %%
    

# Create Dictionary
dictionary = corpora.Dictionary(processed_docs)

# Create Corpus
texts = processed_docs

# 
bow_corpus = [dictionary.doc2bow(text) for text in texts]

# %%
bow_corpus[0]
# Out:
# [(0, 1),
#  (1, 2),
#  (2, 1),
#  (3, 1),
#  (4, 1),
#  (5, 4),
#  (6, 1),
#  (7, 4),
#  (8, 1),
#  (9, 2),
#  (10, 1),
#  (11, 1),
#  (12, 1),
#  (13, 10),
#  (14, 1),
#  (15, 1),
#  (16, 1),
#  (17, 2),
#  (18, 1),
#  (19, 2),
#  (20, 1),
#  (21, 4),
#  (22, 1),
#  (23, 1),
#  (24, 2),
#  (25, 1),
#  (26, 1),
#  (27, 5),
#  (28, 4),
#  (29, 1),
#  (30, 1),
#  (31, 2),
#  (32, 1),
#  (33, 1),
#  (34, 1),
#  (35, 3),
#  (36, 5),
#  (37, 1),
#  (38, 1),
#  (39, 4),
#  (40, 2),
#  (41, 1),
#  (42, 2),
#  (43, 24),
#  (44, 1),
#  (45, 4),
#  (46, 2),
#  (47, 1),
#  (48, 1),
#  (49, 1),
#  (50, 4),
#  (51, 1),
#  (52, 2),
#  (53, 1),
#  (54, 2),
#  (55, 2),
#  (56, 1),
#  (57, 1),
#  (58, 1),
#  (59, 3),
#  (60, 1),
#  (61, 1),
#  (62, 1),
#  (63, 1),
#  (64, 1),
#  (65, 1),
#  (66, 1),
#  (67, 2),
#  (68, 1),
#  (69, 3),
#  (70, 2),
#  (71, 1),
#  (72, 5),
#  (73, 1),
#  (74, 1),
#  (75, 2),
#  (76, 1),
#  (77, 2),
#  (78, 2),
#  (79, 2),
#  (80, 1),
#  (81, 2),
#  (82, 2),
#  (83, 4),
# ...

# %%
from gensim import corpora,models

# %%
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidif = tfidf[bow_corpus]

# %%
len(corpus_tfidf)
# Out:
# 113

# %%
lda_model_1 = gensim.models.ldamodel.LdaModel(corpus=bow_corpus,
                                           id2word=dictionary,
                                           num_topics=3, 
                                           random_state=100,
                                           update_every=1,
                                           
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
lda_model_2 = gensim.models.ldamodel.LdaModel(corpus=corpus_tfidif,
                                           id2word=dictionary,
                                           num_topics=3, 
                                           random_state=20,
                                           update_every=1,
                            
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
lda_model_1.print_topics(num_words=100)
# Out:
# [(0,
# ...

# %%
lda_model_2.print_topics(num_words=100)
# Out:
# [(0,
# ...

# %%
print('nPerplexity Score: ', lda_model_1.log_perplexity(corpus))
coherence_model_lda = gensim.models.CoherenceModel(model=lda_model_1, texts=processed_docs, dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('nCoherence Score: ', coherence_lda)
# Out:
# nPerplexity Score:  -9.191874150221505
# nCoherence Score:  0.36089385597944085

# %%
print('nPerplexity Score: ', lda_model_2.log_perplexity(corpus))
coherence_model_lda = gensim.models.CoherenceModel(model=lda_model_2, texts=processed_docs, dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('nCoherence Score: ', coherence_lda)
# Out:
# nPerplexity Score:  -10.200168735631948
# nCoherence Score:  0.716031879813437

# %%
import pyLDAvis.gensim
import pickle 
import pyLDAvis

# Visualize the topics
pyLDAvis.enable_notebook()

LDAvis_prepared = pyLDAvis.gensim.prepare(lda_model_2, corpus, dictionary)
LDAvis_prepared
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.003955 -0.001908       1        1  46.656189
# 2     -0.003728 -0.002280       2        1  39.890751
# 1     -0.000227  0.004188       3        1  13.453060, topic_info=          Term       Freq      Total Category  logprob  loglift
# 1556   pyvista  11.000000  11.000000  Default  30.0000  30.0000
# 1541      mesh   8.000000   8.000000  Default  29.0000  29.0000
# 4000   mapshap   8.000000   8.000000  Default  28.0000  28.0000
# 3060     pvgeo   8.000000   8.000000  Default  27.0000  27.0000
# 5574  nextflow   8.000000   8.000000  Default  26.0000  26.0000
# ...        ...        ...        ...      ...      ...      ...
# 380      graph   2.179031  12.368237   Topic3  -7.8463   0.2697
# 842      conda   2.213545  13.354860   Topic3  -7.8306   0.2087
# 86      python   2.274671  17.539068   Topic3  -7.8034  -0.0366
# 206      model   2.182298  21.173971   Topic3  -7.8448  -0.2664
# ...

# %%
print(lda_model_2.get_document_topics(bow_corpus[9]))
# Out:
# [(1, 0.77718776), (2, 0.22245097)]

# %%
df['raw_text'][9]
# Out:
# 'ruby-dnn\n\n\n\nruby-dnn is a ruby deep learning library this library supports full connected neural network and convolution neural network\nand recurrent neural network\ncurrently you can get % accuracy with mnist and % with cifar \ninstallation\nadd this line to your application\'s gemfile:\nruby\ngem \'ruby-dnn\'\nand then execute:\n$ bundle\n\nor install it yourself as:\n$ gem install ruby-dnn\n\nusage\nmnist mlp example\n```ruby\nmodel  sequentialnew\nmodel << inputlayernew()\nmodel << densenew()\nmodel << relunew\nmodel << densenew()\nmodel << relunew\nmodel << densenew()\nmodelsetup(adamnew softmaxcrossentropynew)\nmodeltrain(x_train y_train  batch_size:  test: [x_test y_test])\naccuracy loss  modelevaluate(x_test y_test)\nputs "accuracy: #{accuracy}"\nputs "loss: #{loss}"\n```\nwhen create a model with \'define by run\' style:  \n```ruby\nclass mlp < model\n  def initialize\n    super\n    @d  densenew()\n    @d  densenew()\n    @d  densenew()\n  end\ndef forward(x)\n    x  
# ...

# %%
for a,b in bow_corpus[0]:
    print(dictionary[a])
# Out:
# advantage
# afterward
# alabama
# also
# alternative
# anaconda
# archive
# automatically
# case
# change
# changes
# click
# clone
# comands
# command
# commands
# computer
# condaio
# could
# desktop
# developed
# directly
# directory
# download
# downloaded
# earlier
# easily
# either
# email
# enabled
# enter
# example
# extract
# field
# files
# finished
# first
# fixed
# folder
# follow
# following
# forget
# free
# generated
# getting
# github
# githubcom
# gprpy
# gprpygit
# gprpysoftware
# ground
# hear
# help
# initialize
# installation
# installed
# instead
# instructions
# interface
# issue
# january
# june
# latter
# like
# linux
# marcus
# marks
# master
# masterzip
# minicondahtml
# mode
# multiples
# myscriptnamepy
# name
# news
# nsgeophysics
# onto
# open
# origin
# pacheco
# penetrating
# period
# picking
# please
# pointing
# points
# post
# press
# processing
# profile
# programs
# prompt
# pull
# quotation
# radar
# recent
# regular
# replace
# running
# save
# ...

# %%
new_doc = 'this is a visualization software'

# %%
preprocess(new_doc)
# Out:
# ['visual', 'softwar']

# %%
bow_vector = dictionary.doc2bow(preprocess(new_doc))

for index, score in sorted(lda_model_2[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model_2.print_topic(index)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-807-0dd0e71b7822> in <module>
#       1 bow_vector = dictionary.doc2bow(preprocess(new_doc))
#       2
# ----> 3 for index, score in sorted(lda_model_2[bow_vector], key=lambda tup: -1*tup[1]):
#       4     print("Score: {}\t Topic: {}".format(score, lda_model_2.print_topic(index)))
#
# ValueError: too many values to unpack (expected 2)

# %%
print(lda_model_2[bow_vector])
# Out:
# ([(0, 0.044978965), (1, 0.04015582), (2, 0.9148652)], [(104, [2]), (124, [2])], [(104, [(2, 0.9985837)]), (124, [(2, 0.9995214)])])
