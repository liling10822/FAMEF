# %% [markdown]
# # Notebook to balance corpus

# %%
import setup_corpus

# %%
import random
import pandas as pd
import nltk
from nltk.corpus import treebank
#Encounter some errors when we downloaded treebank, so use ssl
import ssl
try:
    _create_unverified_https_context=ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context
nltk.download('treebank')
#----------Download End-------------------

categories = ('extended_description', 'extended_installation', 'extended_invocation', 'extended_citation')


def build_corpora():
    corpora = {}
    for cat in categories:
        corpora[cat] = build_corpus(cat)
    return corpora

def build_corpus(selected_category):
    categories_df = {cat : pd.read_csv(f"./training_corpus/{cat}.csv") for cat in categories}
    negative_sample_size = int(len(categories_df[selected_category]) / 4)
    print(f"Selected Category: {selected_category}")
    for category in categories_df:
        categories_df[category].drop('URL', 1, inplace=True)
        if category != selected_category:
            categories_df[category] = categories_df[category].sample(negative_sample_size)
        categories_df[category] = categories_df[category].assign(**{selected_category: category == selected_category})
        print("{} has {} samples;".format(category, len(categories_df[category])))
        #print(categories_df[category].head())
    treebank_background = pd.DataFrame(map(lambda sent: ' '.join(sent), random.sample(list(treebank.sents()), negative_sample_size)), columns=["excerpt"]).assign(description=False)
    #print("Treebank has {} samples.".format(len(treebank_background)))
    #print("categories_df")
    corpus = pd.concat(categories_df.values(), ignore_index=True, sort=False)
    corpus.append(treebank_background, ignore_index=True, sort=False)
    corpus.fillna(value='', inplace=True)
    return corpus
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     /Users/yidanzhang/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!

# %%
corpus =build_corpora()
# Out:
# Selected Category: extended_description
# extended_description has 414 samples;
# extended_installation has 103 samples;
# extended_invocation has 103 samples;
# extended_citation has 103 samples;
# Selected Category: extended_installation
# extended_description has 274 samples;
# extended_installation has 1096 samples;
# extended_invocation has 274 samples;
# extended_citation has 274 samples;
# Selected Category: extended_invocation
# extended_description has 380 samples;
# extended_installation has 380 samples;
# extended_invocation has 1523 samples;
# extended_citation has 380 samples;
# Selected Category: extended_citation
# extended_description has 102 samples;
# extended_installation has 102 samples;
# extended_invocation has 102 samples;
# extended_citation has 409 samples;

# %%
corpus['extended_installation']
# Out:
#       Unnamed: 0   contributor  \
# 0             57     Allen Mao
# 1            324  Rosna Thomas
# 2            355      Pratheek
# 3            293  Rosna Thomas
# 4            174     Allen Mao
# 5            380        Sharad
# 6            394        Yi Xie
# 7            237     Allen Mao
# 8             98     Allen Mao
# 9            370      Pratheek
# 10            32     Allen Mao
# 11           151     Allen Mao
# 12           280  Rosna Thomas
# 13           283  Rosna Thomas
# 14            20     Allen Mao
# 15           275  Rosna Thomas
# 16           322  Rosna Thomas
# 17           376        Sharad
# 18           326  Rosna Thomas
# 19           398        Yi Xie
# 20           391        Yi Xie
# 21           104     Allen Mao
# 22           337      Pratheek
# 23           264     Allen Mao
# 24           106     Allen Mao
# 25           163     Allen Mao
# 26           266     Allen Mao
# 27             2     Allen Mao
# 28           199     Allen Mao
# 29           232     Allen Mao
# ...          ...           ...
# 1888          89     Allen Mao
# 1889          91     Allen Mao
# 1890          28     Allen Mao
# 1891         167     Allen Mao
# 1892         115     Allen Mao
# 1893         259  Rosna Thomas
# 1894         254  Rosna Thomas
# 1895         162     Allen Mao
# 1896         147     Allen Mao
# 1897         262  Rosna Thomas
# 1898         274  Rosna Thomas
# 1899         118     Allen Mao
# 1900         345      Pratheek
# 1901         332      Pratheek
# 1902         329      Pratheek
# 1903         174     Allen Mao
# 1904         236     Allen Mao
# 1905         160     Allen Mao
# 1906         324      Pratheek
# 1907         318        Sharad
# 1908         255  Rosna Thomas
# 1909         231     Allen Mao
# 1910         215     Allen Mao
# 1911          21     Allen Mao
# 1912         110     Allen Mao
# 1913         114     Allen Mao
# 1914          45     Allen Mao
# 1915          56     Allen Mao
# 1916         261  Rosna Thomas
# 1917         121     Allen Mao
#
#                                                 excerpt  extended_installation
# 0     I hope you enjoy using HyVR much more than I e...                  False
# 1     algorithms for generating songs, images, drawi...                  False
# 2                                      Sequence taggers                  False
# 3     A bot which scrapes almost everything about a ...                  False
# 4            tiles server for live feedback when coding                  False
# 5        With the cv method, stratified is set to false                  False
# 6     EventHub enables companies to do cross device ...                  False
# 7     Filtering/plotting tools built for interactivi...                  False
# 8     Most numerical formats (including IEEE 4- and ...                  False
# 9     Delegator.py is a simple library for dealing w...                  False
# 10    GemPy is a Python-based, open-source library f...                  False
# 11    Nikos Kolotouros provides PyTorch re-implement...                  False
# 12              Dense Human Pose Estimation In The Wild                  False
# 13    DensePose-RCNN is implemented in the Detectron...                  False
# 14    Rain streaks can severely degrade the visibili...                  False
# 15                       The Classical Language Toolkit                  False
# 16    in the process of creating art and music.  Pri...                  False
# 17    LightGBM - high performance gradient boosting ...                  False
# 18    artists and musicians to extend (not replace!)...                  False
# 19    Vega is a visualization grammar, a declarative...                  False
# 20    Airpal is a web-based, query execution tool wh...                  False
# 21    Component-Based: Build encapsulated components...                  False
# 22    Target audience is the natural language proces...                  False
# 23    Faster, Better and Lighter for image processin...                  False
# 24    Detectron is Facebook AI Research's software s...                  False
# 25    Normally, displaying data as longitude, latitu...                  False
# 26    DeepGuidedFilter is the author's implementatio...                  False
# 27    Integral Regression is initially described in ...                  False
# 28    FGFA is end-to-end trainable for the task of v...                  False
# 29    One of the main reasons to bring MeshFix to Py...                  False
# ...                                                 ...                    ...
# 1888                              Carlos da Costa, cako                  False
# 1889             Tristan van Leeuwen, TristanvanLeeuwen                  False
# 1890  In Neural Information Processing Systems (Neur...                  False
# 1891  author       = "Huang, Po-Han and Matzen, Kevi...                  False
# 1892                             Presented at CVPR 2018                  False
# 1893  howpublished = {\url{https://github.com/cltk/c...                  False
# 1894  Kyle P. Johnson et al.. (2014-2019). CLTK: The...                  False
# 1895  author    = {Lai, Wei-Sheng and Huang, Jia-Bin...                  False
# 1896                          @inproceedings{zhu17fgfa,                  False
# 1897     <a name="CitingDensePose"></a>Citing DensePose                  False
# 1898         journal={arXiv preprint arXiv:1611.05431},                  False
# 1899  Warren, C., Giannopoulos, A., & Giannakis I. (...                  False
# 1900         journal={arXiv preprint arXiv:2007.14640},                  False
# 1901                                 language={English}                  False
# 1902                                publisher = {ELRA},                  False
# 1903  This software is based on ideas published ther...                  False
# 1904                                    month = {July},                  False
# 1905  If you find the code and datasets useful in yo...                  False
# 1906  booktitle = {{Proceedings of the LREC 2010 Wor...                  False
# 1907  If you are using the baseline-removal function...                  False
# 1908  A style-neutral BibTeX entry would look like t...                  False
# 1909  Yulun Zhang, Yapeng Tian, Yu Kong, Bineng Zhon...                  False
# 1910                                      pages = {922}                  False
# 1911  and Andrew Tao and Jan Kautz and Bryan Catanza...                  False
# 1912        title={Image Generation from Scene Graphs},                  False
# 1913            Justin Johnson, Agrim Gupta, Li Fei-Fei                  False
# 1914  author = {Zhou, Yanzhao and Zhu, Yi and Ye, Qi...                  False
# 1915  If you use this code or ideas from the paper f...                  False
# 1916                               year = {2014--2019},                  False
# 1917                  @inproceedings{derain_zhang_2018,                  False
#
# [1918 rows x 4 columns]

# %%
corpus['extended_citation'].drop(columns=['Unnamed: 0'],inplace=True)

# %%
corpus['extended_citation']
# Out:
#       contributor                                            excerpt  \
# 0       Allen Mao  construction and interactive editing of spatia...
# 1       Allen Mao     Multivariate method and Parameter Optimization
# 2    Rosna Thomas  the About us &lt;http://scikit-learn.org/dev/a...
# 3          Yi Xie  Apache ECharts (incubating) is a free, powerfu...
# 4       Allen Mao  A scene graph is a structured representation o...
# 5       Allen Mao  FGFA is end-to-end trainable for the task of v...
# 6       Allen Mao  This repository contains a PyTorch implementat...
# 7       Allen Mao                                      Project goals
# 8        Pratheek                                   Text classifiers
# 9       Allen Mao  The goal of Detectron is to provide a high-qua...
# 10      Allen Mao  Diffusive half-space (electric sources and rec...
# 11      Allen Mao  Export meshes as VTK, STL, OBJ, or PLY file types
# 12      Allen Mao  If you give it all of OpenStreetMap and zoom o...
# 13   Rosna Thomas  Magenta is a research project exploring the ro...
# 14      Allen Mao     Remote Geomod: From GoogleEarth to 3-D Geology
# 15      Allen Mao  The follwoing figure gives an illustration of ...
# 16      Allen Mao  dipole: infinitesimal small dipoles oriented a...
# 17      Allen Mao               There's a C++11 port: geojson-vt-cpp
# 18      Allen Mao  React is a JavaScript library for building use...
# 19      Allen Mao  Theano allows the automated computation of gra...
# 20         Sharad  Thanks to the xgboost gem for showing how to u...
# 21      Allen Mao  Digital Linear Filters DLF (using included fil...
# 22      Allen Mao  It now takes a period of time closer to 24 hou...
# 23   Rosna Thomas              TensorFlow and release our models and
# 24      Allen Mao  A Jupyter / Leaflet bridge enabling interactiv...
# 25      Allen Mao  The major contributors of this repository incl...
# 26      Allen Mao  wavenumber: as dipole, but returns the wavenum...
# 27      Allen Mao                        Currently, segyio supports:
# 28      Allen Mao  Sentinelsat makes searching, downloading and r...
# 29      Allen Mao  Component-Based: Build encapsulated components...
# ..            ...                                                ...
# 685       Ling Li  title = {Hand Keypoint Detection in Single Ima...
# 686       Ling Li                                      year = {2017}
# 687       Ling Li                                                  }
# 688       Ling Li                    @inproceedings{cao2017realtime,
# 689       Ling Li  author = {Zhe Cao and Tomas Simon and Shih-En ...
# 690       Ling Li                                booktitle = {CVPR},
# 691       Ling Li  title = {Realtime Multi-Person 2D Pose Estimat...
# 692       Ling Li                                      year = {2017}
# 693       Ling Li                                                  }
# 694       Ling Li                         @inproceedings{wei2016cpm,
# 695       Ling Li  author = {Shih-En Wei and Varun Ramakrishna an...
# 696       Ling Li                                booktitle = {CVPR},
# 697       Ling Li             title = {Convolutional pose machines},
# 698       Ling Li                                      year = {2016}
# 699       Ling Li                                                  }
# 700       Ling Li                               Links to the papers:
# 701       Ling Li  OpenPose: Realtime Multi-Person 2D Pose Estima...
# 702       Ling Li                                         IEEE TPAMI
# 703       Ling Li                                              ArXiv
# 704       Ling Li  Hand Keypoint Detection in Single Images using...
# 705       Ling Li  Realtime Multi-Person 2D Pose Estimation using...
# 706       Ling Li                        Convolutional Pose Machines
# 707        Yi Xie                          Andy Kramolisch @andykram
# 708        Yi Xie                                Harry Shoff @hshoff
# 709        Yi Xie                            Josh Perez @goatslacker
# 710        Yi Xie                            Spike Brehm @spikebrehm
# 711        Yi Xie                      Stefan Vermaas @stefanvermaas
# 712        Yi Xie  Deqing Li, Honghui Mei, Yi Shen, Shuang Su, We...
# 713        Yi Xie                                       MIT License.
# 714        Yi Xie                     Copyright (c) 2014 Ryzac, Inc.
#
#      extended_citation
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# 5                False
# 6                False
# 7                False
# 8                False
# 9                False
# 10               False
# 11               False
# 12               False
# 13               False
# 14               False
# 15               False
# 16               False
# 17               False
# 18               False
# 19               False
# 20               False
# 21               False
# 22               False
# 23               False
# 24               False
# 25               False
# 26               False
# 27               False
# 28               False
# 29               False
# ..                 ...
# 685               True
# 686               True
# 687               True
# 688               True
# 689               True
# 690               True
# 691               True
# 692               True
# 693               True
# 694               True
# 695               True
# 696               True
# 697               True
# 698               True
# 699               True
# 700               True
# 701               True
# 702               True
# 703               True
# 704               True
# 705               True
# 706               True
# 707               True
# 708               True
# 709               True
# 710               True
# 711               True
# 712               True
# 713               True
# 714               True
#
# [715 rows x 3 columns]

# %%
corpus['extended_description'].drop(columns=['Unnamed: 0'],inplace=True)

# %%
corpus['extended_description']
# Out:
#       contributor                                            excerpt  \
# 0       Allen Mao  Puppeteer is a Node library which provides a h...
# 1       Allen Mao  The major contributors of this repository incl...
# 2       Allen Mao  Integral Regression is initially described in ...
# 3       Allen Mao  We build a 3D pose estimation system based mai...
# 4       Allen Mao  The Integral Regression is also known as soft-...
# 5       Allen Mao  This is an official implementation for Integra...
# 6       Allen Mao  The original implementation is based on our in...
# 7       Allen Mao  LibGEOS is a LGPL-licensed package for manipul...
# 8       Allen Mao  Among other things, it allows you to parse Wel...
# 9       Allen Mao  This repository contains the experiments in th...
# 10      Allen Mao  For the results presented in the paper, we did...
# 11      Allen Mao  Batch normalization is currently not supported...
# 12      Allen Mao  Open-source Ground Penetrating Radar processin...
# 13      Allen Mao  Pytorch implementation for high-resolution (e....
# 14      Allen Mao  The PVGeo Python package contains VTK powered ...
# 15      Allen Mao  A PyVista (and VTK) interface for the Open Min...
# 16      Allen Mao  GeoNotebook is an application that provides cl...
# 17      Allen Mao  Fiona is OGR's neat and nimble API for Python ...
# 18      Allen Mao  Fiona is designed to be simple and dependable....
# 19      Allen Mao  Shapely is a BSD-licensed Python package for m...
# 20      Allen Mao  Rain streaks can severely degrade the visibili...
# 21      Allen Mao                       The pytorch branch contains:
# 22      Allen Mao  the pytorch implementation of Peak Response Ma...
# 23      Allen Mao  the PASCAL-VOC demo (training, inference, and ...
# 24      Allen Mao  Lithology and stratigraphic logs for wells and...
# 25      Allen Mao                  This Python module allows you to:
# 26      Allen Mao  Interactively control an instance of ANSYS v14...
# 27      Allen Mao  Extract data directly from binary ANSYS v14.5+...
# 28      Allen Mao  Rapidly read in binary result (.rst), binary m...
# 29      Allen Mao  Official implementation of GANimation. In this...
# ..            ...                                                ...
# 693     Allen Mao  author =       {Ross Girshick and Ilija Radosa...
# 694     Allen Mao                    1NVIDIA Corporation, 2MIT CSAIL
# 695     Allen Mao                  Piotr Doll\'{a}r and Kaiming He},
# 696     Allen Mao                   title={Neural 3D Mesh Renderer},
# 697     Allen Mao  title = {High Performance Visual Tracking With...
# 698   Yidan Zhang    url       = {https://arxiv.org/abs/2001.01215},
# 699     Allen Mao                       @InProceedings{Li_2018_CVPR,
# 700        Yi Xie                      Stefan Vermaas @stefanvermaas
# 701     Allen Mao                      @article{sullivan2019pyvista,
# 702     Allen Mao                                      year = {2018}
# 703   Yidan Zhang             doi       = {10.1145/3319499.3328231},
# 704     Allen Mao  howpublished = {\url{https://github.com/facebo...
# 705     Allen Mao  Proceedings of the ICCV Workshop on Action, Ge...
# 706     Allen Mao                                         References
# 707     Allen Mao  and Andrew Tao and Jan Kautz and Bryan Catanza...
# 708  Rosna Thomas  Stéfan van der Walt, Johannes L. Schönberger, ...
# 709     Allen Mao                                     number = {30},
# 710     Allen Mao  title        = "DeepMVS: Learning Multi-View S...
# 711     Allen Mao  author       = "Huang, Po-Han and Matzen, Kevi...
# 712  Rosna Thomas  If you use scikit-learn in a scientific public...
# 713     Allen Mao  Title = {Flow-Guided Feature Aggregation for V...
# 714        Yi Xie                                Harry Shoff @hshoff
# 715     Allen Mao                       doi = {10.21105/joss.00992},
# 716        Sharad  If you find this software useful, please consi...
# 717     Allen Mao  Xin Tao, Hongyun Gao, Xiaoyong Shen, Jue Wang,...
# 718     Allen Mao   Huikai Wu, Shuai Zheng, Junge Zhang, Kaiqi Huang
# 719   Yidan Zhang                 crossref  = {DBLP:conf/eics/2019},
# 720     Allen Mao                  @inproceedings{zhang2018residual,
# 721     Allen Mao  booktitle    = "IEEE Conference on Computer Vi...
# 722     Allen Mao                         Dieter Werthmüller, prisae
#
#      extended_description
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True
# 5                    True
# 6                    True
# 7                    True
# 8                    True
# 9                    True
# 10                   True
# 11                   True
# 12                   True
# 13                   True
# 14                   True
# 15                   True
# 16                   True
# 17                   True
# 18                   True
# 19                   True
# 20                   True
# 21                   True
# 22                   True
# 23                   True
# 24                   True
# 25                   True
# 26                   True
# 27                   True
# 28                   True
# 29                   True
# ..                    ...
# 693                 False
# 694                 False
# 695                 False
# 696                 False
# 697                 False
# 698                 False
# 699                 False
# 700                 False
# 701                 False
# 702                 False
# 703                 False
# 704                 False
# 705                 False
# 706                 False
# 707                 False
# 708                 False
# 709                 False
# 710                 False
# 711                 False
# 712                 False
# 713                 False
# 714                 False
# 715                 False
# 716                 False
# 717                 False
# 718                 False
# 719                 False
# 720                 False
# 721                 False
# 722                 False
#
# [723 rows x 3 columns]

# %%
corpus['extended_invocation'].drop(columns=['Unnamed: 0'],inplace=True)

# %%
corpus['extended_invocation']
# Out:
#        contributor                                            excerpt  \
# 0        Allen Mao  Each branch in the git repository corresponds ...
# 1           Sharad  lakeFS is an open source layer that delivers r...
# 2         Pratheek                          Core PyText features:\n\n
# 3        Allen Mao  Official implementation of Fast End-to-End Tra...
# 4        Allen Mao  TensorFlow is an open source software library ...
# 5        Allen Mao  This software takes as input a polygon mesh an...
# 6        Allen Mao  Direct access to mesh analysis and transformat...
# 7        Allen Mao  gprMax is open source software that simulates ...
# 8        Allen Mao  Among other things, it allows you to parse Wel...
# 9        Allen Mao  Segyio is a small LGPL licensed C library for ...
# 10    Rosna Thomas  artists and musicians to extend (not replace!)...
# 11    Rosna Thomas                     The Classical Language Toolkit
# 12       Allen Mao  This is a yeoman generator for ArcGIS API for ...
# 13        Pratheek  Alleviate the pain of Dataset handling. Users ...
# 14    Rosna Thomas  ResNeXt: Aggregated Residual Transformations f...
# 15       Allen Mao  The goal of Detectron is to provide a high-qua...
# 16          Yi Xie                     Fast interactive HTML5 charts.
# 17        Pratheek  easy to plug in your own input corpus/datastre...
# 18       Allen Mao  Fourier transforms (space-frequency to space-t...
# 19    Rosna Thomas  these models.  Magenta was started by some res...
# 20     Yidan Zhang  TensorWatch is a debugging and visualization t...
# 21       Allen Mao  We proposed to evaluate the detection accuracy...
# 22       Allen Mao  New developments in the field of augmented rea...
# 23    Rosna Thomas  ResNeXt is a simple, highly modularized networ...
# 24          Sharad  This library supports full connected neural ne...
# 25       Allen Mao  For simplicity, each dot represents one U-Net....
# 26       Allen Mao  This is a Python 2.7 and 3.3+ package to read ...
# 27          Yi Xie  EventHub enables companies to do cross device ...
# 28         Ling Li   Starting with a Hello World version, followed...
# 29       Allen Mao  gprMax is principally written in Python 3 with...
# ...            ...                                                ...
# 2633     Allen Mao  title = {Enhanced Deep Residual Networks for S...
# 2634     Allen Mao                                      year = {2017}
# 2635   Yidan Zhang  title={{CASPR}: A Comprehensive Cable-Robot An...
# 2636     Allen Mao  If you find Integral Regression useful in your...
# 2637     Allen Mao                  @inproceedings{tang2018quantized,
# 2638       Ling Li                      @inproceedings{simon2017hand,
# 2639     Allen Mao                               @misc{Detectron2018,
# 2640       Ling Li                                         IEEE TPAMI
# 2641     Allen Mao  Key Laboratory of Machine Perception (MOE), Sc...
# 2642     Allen Mao  title={Scale-recurrent Network for Deep Image ...
# 2643      Pratheek                                                  }
# 2644     Allen Mao  title={Can Spatiotemporal 3D CNNs Retrace the ...
# 2645     Allen Mao  Yulun Zhang, Yapeng Tian, Yu Kong, Bineng Zhon...
# 2646     Allen Mao  author = {Lim, Bee and Son, Sanghyun and Kim, ...
# 2647     Allen Mao                    publisher = {The Open Journal},
# 2648     Allen Mao                                author = {Yu, Hao},
# 2649     Allen Mao  Sullivan et al., (2019). PyVista: 3D plotting ...
# 2650       Ling Li                    @inproceedings{cao2017realtime,
# 2651  Rosna Thomas                                          Citations
# 2652     Allen Mao  author       = "Huang, Po-Han and Matzen, Kevi...
# 2653       Ling Li                                      year = {2017}
# 2654     Allen Mao                        @INPROCEEDINGS{Zhou2018PRM,
# 2655  Rosna Thomas       journal = {arXiv preprint arXiv:1810.09538},
# 2656     Allen Mao          author = {Xinlei Chen and Abhinav Gupta},
# 2657        Sharad  L. P. René de Cotret, M. R. Otto, M. J. Stern....
# 2658   Yidan Zhang  author={Lau, Darwin and Eden, Jonathan and Tan...
# 2659  Rosna Thomas     <a name="CitingDensePose"></a>Citing DensePose
# 2660     Allen Mao                                      volume = {4},
# 2661   Yidan Zhang                       @inproceedings{lau2016CASPR,
# 2662     Allen Mao  Proceedings of the IEEE Conference on Computer...
#
#       extended_invocation
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# 5                   False
# 6                   False
# 7                   False
# 8                   False
# 9                   False
# 10                  False
# 11                  False
# 12                  False
# 13                  False
# 14                  False
# 15                  False
# 16                  False
# 17                  False
# 18                  False
# 19                  False
# 20                  False
# 21                  False
# 22                  False
# 23                  False
# 24                  False
# 25                  False
# 26                  False
# 27                  False
# 28                  False
# 29                  False
# ...                   ...
# 2633                False
# 2634                False
# 2635                False
# 2636                False
# 2637                False
# 2638                False
# 2639                False
# 2640                False
# 2641                False
# 2642                False
# 2643                False
# 2644                False
# 2645                False
# 2646                False
# 2647                False
# 2648                False
# 2649                False
# 2650                False
# 2651                False
# 2652                False
# 2653                False
# 2654                False
# 2655                False
# 2656                False
# 2657                False
# 2658                False
# 2659                False
# 2660                False
# 2661                False
# 2662                False
#
# [2663 rows x 3 columns]

# %% [markdown]
# # Distribution of Data

# %% [markdown]
# # For Invocation

# %%
corpus['extended_invocation']['extended_invocation'].value_counts()
# Out:
# True     1523
# False    1140
# Name: extended_invocation, dtype: int64

# %% [markdown]
# # For Installation

# %%
corpus['extended_installation']['extended_installation'].value_counts()
# Out:
# True     1096
# False     822
# Name: extended_installation, dtype: int64

# %% [markdown]
# # For Citation

# %%
corpus['extended_citation']['extended_citation'].value_counts()
# Out:
# True     409
# False    306
# Name: extended_citation, dtype: int64

# %% [markdown]
# # For Description

# %%
corpus['extended_description']['extended_description'].value_counts()
# Out:
# True     414
# False    309
# Name: extended_description, dtype: int64

# %% [markdown]
# # Bar Plots

# %% [markdown]
# # Extended Installation

# %%
corpus['extended_installation']['extended_installation'].value_counts().sort_values().plot(kind = 'bar')

# %% [markdown]
# # Extended Invocation

# %%
corpus['extended_invocation']['extended_invocation'].value_counts().sort_values().plot(kind = 'bar')

# %% [markdown]
# # Extended Description

# %%
corpus['extended_description']['extended_description'].value_counts().sort_values().plot(kind = 'bar')

# %% [markdown]
# # Exteneded Citation

# %%
corpus['extended_citation']['extended_citation'].value_counts().sort_values().plot(kind = 'bar')
