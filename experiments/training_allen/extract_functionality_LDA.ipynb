# %%
import os
import pandas as pd
import re
import nltk
from string import punctuation

# %%
import gensim
from gensim.utils import simple_preprocess

# %%
from nltk.stem import WordNetLemmatizer, SnowballStemmer

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_md')

# %%
import markdown
from bs4 import BeautifulSoup

# %%
description_file ='../training_corpus/extended_description.csv'

# %%
description_df = pd.read_csv(description_file)

# %%
description_df.columns
# Out:
# Index(['Unnamed: 0', 'URL', 'contributor', 'excerpt'], dtype='object')

# %%
description_df.drop(columns='Unnamed: 0',inplace=True,)

# %%
description_df.head()
# Out:
#                                                 URL contributor  \
# 0         https://github.com/GoogleChrome/puppeteer   Allen Mao
# 1  https://github.com/JimmySuen/integral-human-pose   Allen Mao
# 2  https://github.com/JimmySuen/integral-human-pose   Allen Mao
# 3  https://github.com/JimmySuen/integral-human-pose   Allen Mao
# 4  https://github.com/JimmySuen/integral-human-pose   Allen Mao
#
#                                              excerpt
# 0  Puppeteer is a Node library which provides a h...
# 1  The major contributors of this repository incl...
# 2  Integral Regression is initially described in ...
# 3  We build a 3D pose estimation system based mai...
# 4  The Integral Regression is also known as soft-...

# %%
description_df.head(20)
# Out:
#                                                  URL contributor  \
# 0          https://github.com/GoogleChrome/puppeteer   Allen Mao
# 1   https://github.com/JimmySuen/integral-human-pose   Allen Mao
# 2   https://github.com/JimmySuen/integral-human-pose   Allen Mao
# 3   https://github.com/JimmySuen/integral-human-pose   Allen Mao
# 4   https://github.com/JimmySuen/integral-human-pose   Allen Mao
# 5   https://github.com/JimmySuen/integral-human-pose   Allen Mao
# 6   https://github.com/JimmySuen/integral-human-pose   Allen Mao
# 7             https://github.com/JuliaGeo/LibGEOS.jl   Allen Mao
# 8             https://github.com/JuliaGeo/LibGEOS.jl   Allen Mao
# 9        https://github.com/LMescheder/GAN_stability   Allen Mao
# 10       https://github.com/LMescheder/GAN_stability   Allen Mao
# 11       https://github.com/LMescheder/GAN_stability   Allen Mao
# 12             https://github.com/NSGeophysics/GPRPy   Allen Mao
# 13                 https://github.com/NVIDIA/vid2vid   Allen Mao
# 14               https://github.com/OpenGeoVis/PVGeo   Allen Mao
# 15            https://github.com/OpenGeoVis/omfvista   Allen Mao
# 16    https://github.com/OpenGeoscience/geonotebook/   Allen Mao
# 17               https://github.com/Toblerity/Fiona/   Allen Mao
# 18               https://github.com/Toblerity/Fiona/   Allen Mao
# 19              https://github.com/Toblerity/Shapely   Allen Mao
#
#                                               excerpt
# 0   Puppeteer is a Node library which provides a h...
# 1   The major contributors of this repository incl...
# 2   Integral Regression is initially described in ...
# 3   We build a 3D pose estimation system based mai...
# 4   The Integral Regression is also known as soft-...
# 5   This is an official implementation for Integra...
# 6   The original implementation is based on our in...
# 7   LibGEOS is a LGPL-licensed package for manipul...
# 8   Among other things, it allows you to parse Wel...
# 9   This repository contains the experiments in th...
# 10  For the results presented in the paper, we did...
# 11  Batch normalization is currently not supported...
# 12  Open-source Ground Penetrating Radar processin...
# 13  Pytorch implementation for high-resolution (e....
# 14  The PVGeo Python package contains VTK powered ...
# 15  A PyVista (and VTK) interface for the Open Min...
# 16  GeoNotebook is an application that provides cl...
# 17  Fiona is OGR's neat and nimble API for Python ...
# 18  Fiona is designed to be simple and dependable....
# 19  Shapely is a BSD-licensed Python package for m...

# %%
df =description_df.groupby('URL').agg(''.join).reset_index()

# %%
df.head()
# Out:
#                                                  URL  \
# 0  https://github.com/CMU-Perceptual-Computing-La...
# 1             https://github.com/Codecademy/EventHub
# 2          https://github.com/GoogleChrome/puppeteer
# 3       https://github.com/HumbleSoftware/envisionjs
# 4                https://github.com/JaidedAI/EasyOCR
#
#                 contributor                                            excerpt
# 0                   Ling Li  OpenPose represents the first real-time multi-...
# 1  Yi XieYi XieYi XieYi Xie  EventHub enables companies to do cross device ...
# 2                 Allen Mao  Puppeteer is a Node library which provides a h...
# 3                    Yi Xie                     Fast interactive HTML5 charts.
# 4                   Ling Li  Ready-to-use OCR with 70+ languages supported ...

# %% [markdown]
# #  preprocessing

# %%
len(df)
# Out:
# 105

# %%
df['excerpt'] = df['excerpt'].map(lambda x: re.sub(r'[\.\?\!,=]','',x))
# remove digits                                      
regex = re.compile(r'\d*')
df['excerpt'] = df['excerpt'].map(lambda x: re.sub(regex,'',x))
# convert to lower case
df['excerpt'] = df['excerpt'].map(lambda x: x.lower())

# %%
df.head()
# Out:
#                                                  URL  \
# 0  https://github.com/CMU-Perceptual-Computing-La...
# 1             https://github.com/Codecademy/EventHub
# 2          https://github.com/GoogleChrome/puppeteer
# 3       https://github.com/HumbleSoftware/envisionjs
# 4                https://github.com/JaidedAI/EasyOCR
#
#                 contributor                                            excerpt
# 0                   Ling Li  openpose represents the first real-time multi-...
# 1  Yi XieYi XieYi XieYi Xie  eventhub enables companies to do cross device ...
# 2                 Allen Mao  puppeteer is a node library which provides a h...
# 3                    Yi Xie                       fast interactive html charts
# 4                   Ling Li  ready-to-use ocr with + languages supported in...

# %%
stemmer = SnowballStemmer('english')
original_words = ['caresses', 'flies', 'dies', 'mules', 'denied','died', 'agreed', 'owned', 
           'humbled', 'sized','meeting', 'stating', 'siezing', 'itemization','sensational', 
           'traditional', 'reference', 'colonizer','plotted']
singles = [stemmer.stem(WordNetLemmatizer().lemmatize(plural)) for plural in original_words]
pd.DataFrame(data = {'original word': original_words, 'stemmed': singles})
# Out:
#    original word stemmed
# 0       caresses  caress
# 1          flies     fli
# 2           dies      dy
# 3          mules    mule
# 4         denied    deni
# 5           died     die
# 6         agreed    agre
# 7          owned     own
# 8        humbled   humbl
# 9          sized    size
# 10       meeting    meet
# 11       stating   state
# 12       siezing    siez
# 13   itemization    item
# 14   sensational  sensat
# 15   traditional  tradit
# 16     reference   refer
# 17     colonizer   colon
# 18       plotted    plot

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
stop_words_new =['code','file','text','use','http','https','install','using','import','python','instal','example','documentation','rain'
                'contains','contain','data','chinese','korean','thai','japanese']

# %%
stop_words.extend(stop_words_new)

# %%
# from nltk.stem import WordNetLemmatizer
# wordnet_lemmatizer = WordNetLemmatizer()
   
    
def preprocess(text):
    result = []
    for token in simple_preprocess(text):
        if token not in stop_words and len(token) > 3:
            
            
            result.append(token)
                
    return result

# %%
processed_docs =df['excerpt'].map(preprocess)

# %%
processed_docs.head()
# Out:
# 0    [openpose, represents, first, real, time, mult...
# 1    [eventhub, enables, companies, cross, device, ...
# 2    [puppeteer, node, library, provides, high, lev...
# 3                    [fast, interactive, html, charts]
# 4             [ready, languages, supported, including]
# Name: excerpt, dtype: object

# %%
import gensim.corpora as corpora

# %%
 

# Create Dictionary
dictionary = corpora.Dictionary(processed_docs)
#dictionary.filter_extremes(no_below=2, no_above=0.8)
dictionary.filter_extremes(no_below=1, no_above=0.8)
print(len(dictionary))
# Create Corpus
texts = processed_docs

# 
bow_corpus = [dictionary.doc2bow(text) for text in texts]
# Out:
# 2399

# %%
from gensim import corpora,models

# %%
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]

# %%
len(corpus_tfidf)
# Out:
# 105

# %%
lda_model_1 = gensim.models.ldamodel.LdaModel(corpus=bow_corpus,
                                           id2word=dictionary,
                                           num_topics=6, 
                                           random_state=100,
                                          
                                           passes=20,
                                           alpha='auto',
                                           per_word_topics=True,minimum_probability=0.001)

# %%
lda_model_2 = gensim.models.ldamodel.LdaModel(corpus=corpus_tfidf,
                                           id2word=dictionary,
                                           num_topics=5, 
                                           random_state=100,
                                          
                                           passes=20,
                                           alpha='auto',
                                           per_word_topics=True,minimum_probability=0.001)

# %%
lda_model_2.print_topics(num_words=30)
# Out:
# [(0,
#   '0.002*"binary" + 0.001*"average" + 0.001*"pyro" + 0.001*"languages" + 0.001*"files" + 0.001*"ready" + 0.001*"supported" + 0.001*"objects" + 0.001*"including" + 0.001*"training" + 0.001*"geos" + 0.001*"latent" + 0.001*"neural" + 0.001*"magenta" + 0.001*"aims" + 0.001*"densepose" + 0.001*"ansys" + 0.001*"algorithms" + 0.001*"fastaifastai" + 0.001*"practices" + 0.001*"welcome" + 0.001*"eventhub" + 0.001*"conversion" + 0.001*"models" + 0.001*"human" + 0.001*"currently" + 0.001*"versions" + 0.001*"dirichlet" + 0.001*"moving" + 0.001*"geometric"'),
#  (1,
#   '0.002*"rain" + 0.002*"network" + 0.002*"pytorch" + 0.002*"scikit" + 0.002*"mapnik" + 0.002*"image" + 0.002*"detection" + 0.002*"implementation" + 0.001*"visualization" + 0.001*"learning" + 0.001*"framework" + 0.001*"pose" + 0.001*"tensor" + 0.001*"faster" + 0.001*"object" + 0.001*"ruby" + 0.001*"reduxperformant" + 0.001*"paper" + 0.001*"server" + 0.001*"features" + 0.001*"residual" + 0.001*"training" + 0.001*"project" + 0.001*"neural" + 0.001*"deep" + 0.001*"tiles" + 0.001*"density" + 0.001*"eccv" + 0.001*"official" + 0.001*"bindings"'),
#  (2,
#   '0.001*"parameter" + 0.001*"nets" + 0.001*"react" + 0.001*"segyio" + 0.001*"processing" + 0.001*"storage" + 0.001*"give" + 0.001*"radar" + 0.001*"classical" + 0.001*"pressure" + 0.001*"biomedical" + 0.001*"mapshaper" + 0.001*"language" + 0.001*"software" + 0.001*"method" + 0.001*"renderer" + 0.001*"penetrating" + 0.001*"cvpr" + 0.001*"geos" + 0.001*"neural" + 0.001*"transformations" + 0.001*"open" + 0.001*"editing" + 0.001*"ground" + 0.001*"contains" + 0.001*"mplleaflet" + 0.001*"basemap" + 0.001*"seismic" + 0.001*"languages" + 0.001*"source"'),
#  (3,
#   '0.002*"resolution" + 0.002*"spatial" + 0.002*"tile" + 0.002*"gitbucket" + 0.001*"gdal" + 0.001*"hyvr" + 0.001*"logs" + 0.001*"matrix" + 0.001*"keypoints" + 0.001*"stratigraphic" + 0.001*"fiona" + 0.001*"wells" + 0.001*"lithology" + 0.001*"super" + 0.001*"space" + 0.001*"reading" + 0.001*"frequency" + 0.001*"root" + 0.001*"package" + 0.001*"runs" + 0.001*"classes" + 0.001*"pyramid" + 0.001*"outcrop" + 0.001*"files" + 0.001*"branch" + 0.001*"operators" + 0.001*"blocking" + 0.001*"useable" + 0.001*"mining" + 0.001*"processing"'),
#  (4,
#   '0.002*"jupyter" + 0.002*"interactive" + 0.001*"software" + 0.001*"scene" + 0.001*"charts" + 0.001*"provides" + 0.001*"visualization" + 0.001*"analysis" + 0.001*"tools" + 0.001*"graph" + 0.001*"open" + 0.001*"queries" + 0.001*"research" + 0.001*"video" + 0.001*"tetgen" + 0.001*"model" + 0.001*"html" + 0.001*"meshes" + 0.001*"cable" + 0.001*"robot" + 0.001*"facebook" + 0.001*"hardware" + 0.001*"input" + 0.001*"translation" + 0.001*"developed" + 0.001*"used" + 0.001*"platform" + 0.001*"plotting" + 0.001*"kitware" + 0.001*"sonnet"')]

# %%
lda_model_2.save('lda.model')

# %%
lda_model = gensim.models.ldamodel.LdaModel.load('lda.model')

# %%
dict(lda_model.id2word)
# Out:
# {0: 'body',
#  1: 'detect',
#  2: 'facial',
#  3: 'first',
#  4: 'foot',
#  5: 'hand',
#  6: 'human',
#  7: 'images',
#  8: 'jointly',
#  9: 'keypoints',
#  10: 'multi',
#  11: 'openpose',
#  12: 'person',
#  13: 'real',
#  14: 'represents',
#  15: 'single',
#  16: 'system',
#  17: 'time',
#  18: 'total',
#  19: 'answer',
#  20: 'associated',
#  21: 'built',
#  22: 'business',
#  23: 'cohorted',
#  24: 'common',
#  25: 'companies',
#  26: 'conversion',
#  27: 'cross',
#  28: 'dashboard',
#  29: 'device',
#  30: 'enables',
#  31: 'event',
#  32: 'eventhub',
#  33: 'events',
#  34: 'following',
#  35: 'funnel',
#  36: 'higher',
#  37: 'joined',
#  38: 'questionswhat',
#  39: 'rate',
#  40: 'ratewhat',
#  41: 'retentionwhich',
#  42: 'test',
#  43: 'tracking',
#  44: 'user',
#  45: 'variant',
#  46: 'visualized',
#  47: 'chrome',
#  48: 'chromium',
#  49: 'configured',
#  50: 'control',
#  51: 'default',
#  52: 'devtools',
#  53: 'full',
#  54: 'headless',
#  55: 'high',
#  56: 'level',
#  57: 'library',
#  58: 'node',
#  59: 'protocol',
#  60: 'provides',
#  61: 'puppeteer',
#  62: 'runs',
#  63: 'charts',
#  64: 'fast',
#  65: 'html',
#  66: 'interactive',
#  67: 'including',
#  68: 'languages',
#  69: 'ready',
#  70: 'supported',
#  71: 'accuracy',
#  72: 'also',
#  73: 'argmax',
#  74: 'augmented',
#  75: 'based',
#  76: 'better',
#  77: 'build',
#  78: 'challenge',
#  79: 'chuankang',
#  80: 'comparision',
#  81: 'comprehensive',
#  82: 'contemporary',
#  83: 'contributors',
#  84: 'currently',
#  85: 'dataset',
#  86: 'described',
#  87: 'details',
#  88: 'differences',
#  89: 'eccv',
#  90: 'estimation',
#  91: 'fangyin',
#  92: 'final',
#  93: 'implementation',
#  94: 'include',
#  95: 'indicating',
#  96: 'initially',
#  97: 'integral',
#  98: 'internal',
#  99: 'known',
#  100: 'luvizon',
#  101: 'mainly',
#  102: 'major',
#  103: 'method',
#  104: 'methodthe',
#  105: 'mxnet',
#  106: 'nibali',
#  107: 'note',
#  108: 'noticing',
#  109: 'official',
#  110: 'original',
#  111: 'paper',
#  112: 'placing',
#  113: 'platform',
#  114: 'please',
#  115: 'plenty',
#  116: 'pose',
#  117: 'pytorch',
#  118: 'refer',
#  119: 'regression',
#  120: 'repository',
#  121: 'running',
#  122: 'sarandi',
#  123: 'second',
#  124: 'slides',
#  125: 'slight',
#  126: 'soft',
#  127: 'state',
#  128: 'switch',
#  129: 'uses',
#  130: 'version',
#  131: 'weiintegral',
#  132: 'winner',
#  133: 'works',
#  134: 'worth',
#  135: 'xiao',
#  136: 'yichen',
#  137: 'allows',
#  138: 'among',
#  139: 'analysis',
#  140: 'engine',
#  141: 'geometric',
#  142: 'geos',
#  143: 'lgpl',
#  144: 'libgeos',
#  145: 'libraries',
#  146: 'licensed',
#  147: 'manipulation',
#  148: 'objects',
#  149: 'package',
#  150: 'parse',
#  151: 'planar',
#  152: 'ported',
#  153: 'postgis',
#  154: 'things',
#  155: 'well',
#  156: 'actually',
#  157: 'average',
#  158: 'buffers',
#  159: 'computed',
#  160: 'contains',
#  161: 'convergefor',
#  162: 'experiments',
#  163: 'exponential',
#  164: 'found',
#  165: 'gans',
#  166: 'helps',
#  167: 'however',
#  168: 'imagenetbatch',
#  169: 'inception',
#  170: 'indeed',
#  171: 'leads',
#  172: 'material',
#  173: 'methods',
#  174: 'model',
#  175: 'models',
#  176: 'moving',
#  177: 'much',
#  178: 'noise',
#  179: 'normalization',
#  180: 'parameters',
#  181: 'presented',
#  182: 'recommend',
#  183: 'reduce',
#  184: 'results',
#  185: 'scores',
#  186: 'supplementary',
#  187: 'therefore',
#  188: 'training',
#  189: 'usage',
#  190: 'weights',
#  191: 'advantage',
#  192: 'aims',
#  193: 'algorithms',
#  194: 'collection',
#  195: 'diffractionit',
#  196: 'electron',
#  197: 'examples',
#  198: 'featuresfor',
#  199: 'fully',
#  200: 'functions',
#  201: 'recent',
#  202: 'taking',
#  203: 'tested',
#  204: 'tutorials',
#  205: 'ultrafast',
#  206: 'ground',
#  207: 'open',
#  208: 'penetrating',
#  209: 'processing',
#  210: 'radar',
#  211: 'software',
#  212: 'source',
#  213: 'visualization',
#  214: 'core',
#  215: 'edge',
#  216: 'generating',
#  217: 'image',
#  218: 'label',
#  219: 'maps',
#  220: 'motions',
#  221: 'people',
#  222: 'photo',
#  223: 'photorealistic',
#  224: 'pixpixhd',
#  225: 'poses',
#  226: 'realistic',
#  227: 'resolution',
#  228: 'semantic',
#  229: 'space',
#  230: 'spade',
#  231: 'synthesizing',
#  232: 'talking',
#  233: 'translation',
#  234: 'turning',
#  235: 'used',
#  236: 'video',
#  237: 'videos',
#  238: 'work',
#  239: 'algorithm',
#  240: 'analyse',
#  241: 'analyzing',
#  242: 'baseline',
#  243: 'building',
#  244: 'clear',
#  245: 'compare',
#  246: 'cosine',
#  247: 'custom',
#  248: 'datasets',
#  249: 'datasetsprovide',
#  250: 'datasurprise',
#  251: 'deal',
#  252: 'designed',
#  253: 'detail',
#  254: 'easily',
#  255: 'easy',
#  256: 'emphasis',
#  257: 'evaluate',
#  258: 'every',
#  259: 'excellent',
#  260: 'exhaustive',
#  261: 'explicit',
#  262: 'factorization',
#  263: 'give',
#  264: 'handling',
#  265: 'ideasprovide',
#  266: 'implement',
#  267: 'inmake',
#  268: 'inspired',
#  269: 'iterators',
#  270: 'jester',
#  271: 'laid',
#  272: 'learn',
#  273: 'make',
#  274: 'many',
#  275: 'matrix',
#  276: 'measures',
#  277: 'mind',
#  278: 'movielens',
#  279: 'neighborhood',
#  280: 'others',
#  281: 'pain',
#  282: 'pearson',
#  283: 'perfect',
#  284: 'performance',
#  285: 'pointing',
#  286: 'possible',
#  287: 'powerful',
#  288: 'precise',
#  289: 'prediction',
#  290: 'procedures',
#  291: 'purposes',
#  292: 'rating',
#  293: 'recommender',
#  294: 'scikit',
#  295: 'search',
#  296: 'similarity',
#  297: 'strong',
#  298: 'surprise',
#  299: 'systems',
#  300: 'tools',
#  301: 'tried',
#  302: 'users',
#  303: 'validation',
#  304: 'various',
#  305: 'application',
#  306: 'direct',
#  307: 'environment',
#  308: 'focus',
#  309: 'geophysics',
#  310: 'geosciences',
#  311: 'grids',
#  312: 'heavy',
#  313: 'kitware',
#  314: 'like',
#  315: 'paraview',
#  316: 'powered',
#  317: 'pvgeo',
#  318: 'pyvista',
#  319: 'sets',
#  320: 'structured',
#  321: 'tailored',
#  322: 'varying',
#  323: 'within',
#  324: 'wrapped',
#  325: 'format',
#  326: 'interface',
#  327: 'mesh',
#  328: 'mining',
#  329: 'providing',
#  330: 'specification',
#  331: 'structures',
#  332: 'useable',
#  333: 'ames',
#  334: 'capabilities',
#  335: 'client',
#  336: 'developed',
#  337: 'geojs',
#  338: 'geonotebook',
#  339: 'jupyter',
#  340: 'nasa',
#  341: 'server',
#  342: 'allocation',
#  343: 'audience',
#  344: 'cluster',
#  345: 'community',
#  346: 'computers',
#  347: 'computing',
#  348: 'corporatarget',
#  349: 'corpus',
#  350: 'datastream',
#  351: 'deep',
#  352: 'dirichlet',
#  353: 'document',
#  354: 'efficient',
#  355: 'extend',
#  356: 'gensim',
#  357: 'hierarchical',
#  358: 'implementations',
#  359: 'independent',
#  360: 'indexing',
#  361: 'information',
#  362: 'input',
#  363: 'language',
#  364: 'large',
#  365: 'larger',
#  366: 'latent',
#  367: 'memory',
#  368: 'modelling',
#  369: 'multicore',
#  370: 'natural',
#  371: 'online',
#  372: 'plug',
#  373: 'popular',
#  374: 'process',
#  375: 'projections',
#  376: 'random',
#  377: 'retrieval',
#  378: 'size',
#  379: 'streamed',
#  380: 'streaming',
#  381: 'topic',
#  382: 'transformation',
#  383: 'trivial',
#  384: 'vector',
#  385: 'wordvec',
#  386: 'apache',
#  387: 'bolt',
#  388: 'java',
#  389: 'neoj',
#  390: 'project',
#  391: 'tinkerpop',
#  392: 'classes',
#  393: 'cpython',
#  394: 'dependable',
#  395: 'dictionaries',
#  396: 'familiar',
#  397: 'files',
#  398: 'fiona',
#  399: 'focuses',
#  400: 'formats',
#  401: 'instead',
#  402: 'integrates',
#  403: 'layered',
#  404: 'mappings',
#  405: 'neat',
#  406: 'nimble',
#  407: 'packages',
#  408: 'protocols',
#  409: 'pyproj',
#  410: 'read',
#  411: 'readily',
#  412: 'reading',
#  413: 'relies',
#  414: 'rtree',
#  415: 'shapely',
#  416: 'simple',
#  417: 'specific',
#  418: 'standard',
#  419: 'style',
#  420: 'types',
#  421: 'upon',
#  422: 'versions',
#  423: 'virtual',
#  424: 'world',
#  425: 'write',
#  426: 'writing',
#  427: 'zipped',
#  428: 'concerned',
#  429: 'coordinate',
#  430: 'deployed',
#  431: 'integrated',
#  432: 'widely',
#  433: 'according',
#  434: 'accumulation',
#  435: 'acquire',
#  436: 'adopt',
#  437: 'alpha',
#  438: 'approaches',
#  439: 'architecture',
#  440: 'assign',
#  441: 'benefit',
#  442: 'block',
#  443: 'causes',
#  444: 'computer',
#  445: 'conduct',
#  446: 'contextual',
#  447: 'convolutional',
#  448: 'current',
#  449: 'decompose',
#  450: 'degrade',
#  451: 'deraining',
#  452: 'different',
#  453: 'dilated',
#  454: 'directions',
#  455: 'evaluation',
#  456: 'excitation',
#  457: 'extensive',
#  458: 'fail',
#  459: 'field',
#  460: 'important',
#  461: 'incorporated',
#  462: 'incorporating',
#  463: 'intensity',
#  464: 'later',
#  465: 'layers',
#  466: 'metrics',
#  467: 'modify',
#  468: 'multiple',
#  469: 'necessary',
#  470: 'network',
#  471: 'networks',
#  472: 'neural',
#  473: 'novel',
#  474: 'outperforms',
#  475: 'overlap',
#  476: 'preserve',
#  477: 'previous',
#  478: 'propose',
#  479: 'proposed',
#  480: 'rain',
#  481: 'receptive',
#  482: 'recurrent',
#  483: 'regarded',
#  484: 'removal',
#  485: 'remove',
#  486: 'severely',
#  487: 'shapes',
#  488: 'since',
#  489: 'squeeze',
#  490: 'stage',
#  491: 'stages',
#  492: 'streak',
#  493: 'streaks',
#  494: 'synthetic',
#  495: 'task',
#  496: 'transparency',
#  497: 'useful',
#  498: 'values',
#  499: 'visibility',
#  500: 'vision',
#  501: 'backprop',
#  502: 'branch',
#  503: 'demo',
#  504: 'inference',
#  505: 'mapping',
#  506: 'pascal',
#  507: 'peak',
#  508: 'response',
#  509: 'stimulation',
#  510: 'lithology',
#  511: 'logs',
#  512: 'outcrop',
#  513: 'stratigraphic',
#  514: 'wells',
#  515: 'ability',
#  516: 'airpal',
#  517: 'authoring',
#  518: 'back',
#  519: 'browse',
#  520: 'browser',
#  521: 'download',
#  522: 'edit',
#  523: 'execution',
#  524: 'facebook',
#  525: 'find',
#  526: 'finished',
#  527: 'friends',
#  528: 'generate',
#  529: 'history',
#  530: 'hive',
#  531: 'leverages',
#  532: 'maintains',
#  533: 'metadata',
#  534: 'prestodb',
#  535: 'progress',
#  536: 'queries',
#  537: 'query',
#  538: 'retrieving',
#  539: 'rows',
#  540: 'sample',
#  541: 'searchable',
#  542: 'share',
#  543: 'submit',
#  544: 'subsequent',
#  545: 'table',
#  546: 'tables',
#  547: 'tool',
#  548: 'track',
#  549: 'animate',
#  550: 'ansys',
#  551: 'archive',
#  552: 'ascii',
#  553: 'binary',
#  554: 'directly',
#  555: 'display',
#  556: 'instance',
#  557: 'interactively',
#  558: 'linux',
#  559: 'mass',
#  560: 'module',
#  561: 'result',
#  562: 'stiffness',
#  563: 'themrapidly',
#  564: 'windowsextract',
#  565: 'action',
#  566: 'activation',
#  567: 'anatomical',
#  568: 'annotations',
#  569: 'approach',
#  570: 'combine',
#  571: 'conditioning',
#  572: 'continuous',
#  573: 'controlling',
#  574: 'defining',
#  575: 'describe',
#  576: 'expression',
#  577: 'ganimation',
#  578: 'immoral',
#  579: 'introduce',
#  580: 'made',
#  581: 'magnitude',
#  582: 'manifold',
#  583: 'movements',
#  584: 'paperthis',
#  585: 'permits',
#  586: 'public',
#  587: 'research',
#  588: 'scheme',
#  589: 'scientific',
#  590: 'several',
#  591: 'units',
#  592: 'blocking',
#  593: 'chain',
#  594: 'commands',
#  595: 'dealing',
#  596: 'delegatorchain',
#  597: 'delegatorpy',
#  598: 'delegatorrun',
#  599: 'depends',
#  600: 'envoy',
#  601: 'fact',
#  602: 'features',
#  603: 'main',
#  604: 'operator',
#  605: 'pexpect',
#  606: 'pipe',
#  607: 'separated',
#  608: 'subprocesses',
#  609: 'unix',
#  610: 'boosting',
#  611: 'falsethanks',
#  612: 'follows',
#  613: 'get_',
#  614: 'gradient',
#  615: 'lightgbm',
#  616: 'methodsthe',
#  617: 'prefixes',
#  618: 'removed',
#  619: 'rubythis',
#  620: 'set_',
#  621: 'showing',
#  622: 'stratified',
#  623: 'verbosity',
#  624: 'xgboost',
#  625: 'adding',
#  626: 'canvas',
#  627: 'charting',
#  628: 'commercial',
#  629: 'customizable',
#  630: 'echarts',
#  631: 'free',
#  632: 'highly',
#  633: 'incubating',
#  634: 'intuitive',
#  635: 'javascript',
#  636: 'lightweight',
#  637: 'offering',
#  638: 'products',
#  639: 'pure',
#  640: 'whole',
#  641: 'written',
#  642: 'zrender',
#  643: 'accessible',
#  644: 'achieved',
#  645: 'addition',
#  646: 'additional',
#  647: 'address',
#  648: 'advanced',
#  649: 'allow',
#  650: 'allowing',
#  651: 'applications',
#  652: 'automated',
#  653: 'automatically',
#  654: 'basis',
#  655: 'bayesian',
#  656: 'beamer',
#  657: 'beginning',
#  658: 'blended',
#  659: 'boundaries',
#  660: 'calcagno',
#  661: 'calculated',
#  662: 'camera',
#  663: 'capable',
#  664: 'carlo',
#  665: 'cokriging',
#  666: 'combining',
#  667: 'complex',
#  668: 'comprehend',
#  669: 'computation',
#  670: 'considered',
#  671: 'considering',
#  672: 'construct',
#  673: 'constructing',
#  674: 'contact',
#  675: 'container',
#  676: 'continuously',
#  677: 'coordinates',
#  678: 'couple',
#  679: 'coupling',
#  680: 'cuda',
#  681: 'date',
#  682: 'dedicated',
#  683: 'definition',
#  684: 'dependencies',
#  685: 'determined',
#  686: 'development',
#  687: 'developments',
#  688: 'devised',
#  689: 'digital',
#  690: 'dimensional',
#  691: 'dipping',
#  692: 'diverse',
#  693: 'docker',
#  694: 'door',
#  695: 'effort',
#  696: 'elements',
#  697: 'elevation',
#  698: 'embedding',
#  699: 'enabling',
#  700: 'exact',
#  701: 'except',
#  702: 'exercise',
#  703: 'exhibit',
#  704: 'exploited',
#  705: 'exportes',
#  706: 'extended',
#  707: 'facts',
#  708: 'fault',
#  709: 'filled',
#  710: 'folded',
#  711: 'framework',
#  712: 'frameworks',
#  713: 'frameworkwe',
#  714: 'functional',
#  715: 'gempy',
#  716: 'generated',
#  717: 'geological',
#  718: 'geologywe',
#  719: 'geomod',
#  720: 'geomodeling',
#  721: 'geophysical',
#  722: 'geoscientific',
#  723: 'githubcom',
#  724: 'global',
#  725: 'googleearth',
#  726: 'googleearthnew',
#  727: 'gpus',
#  728: 'gradients',
#  729: 'great',
#  730: 'hamiltonian',
#  731: 'hardly',
#  732: 'hosted',
#  733: 'imagefinally',
#  734: 'implemented',
#  735: 'implicit',
#  736: 'implicitly',
#  737: 'initial',
#  738: 'installation',
#  739: 'installed',
#  740: 'interact',
#  741: 'interaction',
#  742: 'interactivity',
#  743: 'interesting',
#  744: 'interfaces',
#  745: 'interpolation',
#  746: 'intersected',
#  747: 'intricate',
#  748: 'itgempy',
#  749: 'lajaunie',
#  750: 'layer',
#  751: 'lectures',
#  752: 'making',
#  753: 'maniulation',
#  754: 'marking',
#  755: 'matplotlib',
#  756: 'meaning',
#  757: 'means',
#  758: 'measurement',
#  759: 'measurements',
#  760: 'modeling',
#  761: 'modelsremote',
#  762: 'modification',
#  763: 'monte',
#  764: 'motivate',
#  765: 'nally',
#  766: 'nature',
#  767: 'needs',
#  768: 'numerical',
#  769: 'numerous',
#  770: 'obtain',
#  771: 'ocker',
#  772: 'offer',
#  773: 'offered',
#  774: 'offers',
#  775: 'onto',
#  776: 'opening',
#  777: 'operating',
#  778: 'operation',
#  779: 'orientation',
#  780: 'outreach',
#  781: 'paraviewgempy',
#  782: 'particular',
#  783: 'perpendicular',
#  784: 'planes',
#  785: 'point',
#  786: 'points',
#  787: 'poles',
#  788: 'position',
#  789: 'possibilities',
#  790: 'potential',
#  791: 'precompiled',
#  792: 'probabilistic',
#  793: 'processgempy',
#  794: 'programming',
#  795: 'projected',
#  796: 'prototyping',
#  797: 'provide',
#  798: 'pymc',
#  799: 'qgrid',
#  800: 'quantopian',
#  801: 'questions',
#  802: 'rapid',
#  803: 'reality',
#  804: 'realization',
#  805: 'realizations',
#  806: 'region',
#  807: 'reimported',
#  808: 'relevance',
#  809: 'relevant',
#  810: 'required',
#  811: 'respect',
#  812: 'sampling',
#  813: 'sand',
#  814: 'sandbox',
#  815: 'scanned',
#  816: 'secondary',
#  817: 'sections',
#  818: 'selected',
#  819: 'selection',
#  820: 'sensor',
#  821: 'sequences',
#  822: 'shaped',
#  823: 'shared',
#  824: 'simulation',
#  825: 'simulations',
#  826: 'spacegempy',
#  827: 'steps',
#  828: 'stochastic',
#  829: 'structural',
#  830: 'subsequently',
#  831: 'subsurface',
#  832: 'superimposition',
#  833: 'support',
#  834: 'surface',
#  835: 'surfaces',
#  836: 'surfacesthe',
#  837: 'teaching',
#  838: 'thanks',
#  839: 'theano',
#  840: 'three',
#  841: 'tiny',
#  842: 'toolkit',
#  843: 'topography',
#  844: 'topological',
#  845: 'uncertainties',
#  846: 'uncertainty',
#  847: 'unconformities',
#  848: 'universal',
#  849: 'visualizes',
#  850: 'wayin',
#  851: 'working',
#  852: 'akkadian',
#  853: 'ancient',
#  854: 'classical',
#  855: 'cltk',
#  856: 'collect',
#  857: 'compile',
#  858: 'complete',
#  859: 'corpora',
#  860: 'eurasia',
#  861: 'friendly',
#  862: 'germanic',
#  863: 'goals',
#  864: 'greek',
#  865: 'latin',
#  866: 'linguistic',
#  867: 'medieval',
#  868: 'toolkitthe',
#  869: 'addresses',
#  870: 'atmosphere',
#  871: 'computational',
#  872: 'configurable',
#  873: 'customized',
#  874: 'efforts',
#  875: 'growing',
#  876: 'plant',
#  877: 'resources',
#  878: 'sciences',
#  879: 'bring',
#  880: 'browsers',
#  881: 'combines',
#  882: 'design',
#  883: 'driven',
#  884: 'freedom',
#  885: 'giving',
#  886: 'life',
#  887: 'modern',
#  888: 'right',
#  889: 'standards',
#  890: 'techniques',
#  891: 'visual',
#  892: 'visualizing',
#  893: 'arbitrary',
#  894: 'cable',
#  895: 'caspr',
#  896: 'facilitates',
#  897: 'matlab',
#  898: 'range',
#  899: 'robot',
#  900: 'abstractions',
#  901: 'composable',
#  902: 'encouraged',
#  903: 'learning',
#  904: 'machine',
#  905: 'reinforcement',
#  906: 'researchit',
#  907: 'ship',
#  908: 'sonnet',
#  909: 'supervised',
#  910: 'tensorflow',
#  911: 'able',
#  912: 'approximate',
#  913: 'available',
#  914: 'azimuth',
#  915: 'bedding',
#  916: 'behaviour',
#  917: 'concepts',
#  918: 'conductivity',
#  919: 'course',
#  920: 'created',
#  921: 'deposits',
#  922: 'distributed',
#  923: 'documentationi',
#  924: 'enjoy',
#  925: 'enjoyed',
#  926: 'explore',
#  927: 'facilitated',
#  928: 'fields',
#  929: 'flow',
#  930: 'forward',
#  931: 'funky',
#  932: 'geofantasy',
#  933: 'groundwater',
#  934: 'heterogeneity',
#  935: 'hope',
#  936: 'hydraulic',
#  937: 'hydrogeological',
#  938: 'hyvr',
#  939: 'kind',
#  940: 'lack',
#  941: 'look',
#  942: 'motivation',
#  943: 'needsthe',
#  944: 'outputs',
#  945: 'parameter',
#  946: 'practitioners',
#  947: 'putting',
#  948: 'realitythe',
#  949: 'researchers',
#  950: 'scales',
#  951: 'sedimentary',
#  952: 'seeing',
#  953: 'simulate',
#  954: 'site',
#  955: 'solute',
#  956: 'spatially',
#  957: 'structure',
#  958: 'suit',
#  959: 'take',
#  960: 'technical',
#  961: 'tensors',
#  962: 'together',
#  963: 'transport',
#  964: 'unique',
#  965: 'appears',
#  966: 'architectures',
#  967: 'area',
#  968: 'behavior',
#  969: 'check',
#  970: 'clouds',
#  971: 'comprehensively',
#  972: 'could',
#  973: 'curve',
#  974: 'cvpr',
#  975: 'dbnet',
#  976: 'deeper',
#  977: 'difficult',
#  978: 'driving',
#  979: 'error',
#  980: 'errors',
#  981: 'evaluatepy',
#  982: 'feature',
#  983: 'introductionin',
#  984: 'leveraging',
#  985: 'mean',
#  986: 'measure',
#  987: 'namely',
#  988: 'nvidia_pn',
#  989: 'partial',
#  990: 'prepared',
#  991: 'release',
#  992: 'released',
#  993: 'scale',
#  994: 'scripts',
#  995: 'soon',
#  996: 'thresholds',
#  997: 'webpage',
#  998: 'ending',
#  999: 'followed',
#  ...}

# %%
print('nPerplexity Score: ', lda_model_1.log_perplexity(bow_corpus))
coherence_model_lda = gensim.models.CoherenceModel(model=lda_model_1, texts=processed_docs, dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('nCoherence Score: ', coherence_lda)
# Out:
# nPerplexity Score:  -7.705747381699175
# nCoherence Score:  0.3929166470668761

# %%
print('nPerplexity Score: ', lda_model_2.log_perplexity(corpus_tfidf))
coherence_model_lda = gensim.models.CoherenceModel(model=lda_model_2, texts=processed_docs, dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('nCoherence Score: ', coherence_lda)
# Out:
# nPerplexity Score:  -10.253577130705871
# nCoherence Score:  0.592854816303672

# %%
import pyLDAvis.gensim
import pickle 
import pyLDAvis

# Visualize the topics
pyLDAvis.enable_notebook()

LDAvis_prepared = pyLDAvis.gensim.prepare(lda_model_1, bow_corpus, dictionary,sort_topics=False)
LDAvis_prepared
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.016737 -0.066131       1        1   9.714568
# 1     -0.047360 -0.115303       2        1  17.207823
# 2      0.013549 -0.000554       3        1  11.911898
# 3      0.062047  0.021906       4        1  12.544563
# 4      0.116501  0.051416       5        1  22.982517
# 5     -0.128000  0.108666       6        1  25.638634, topic_info=          Term       Freq      Total Category  logprob  loglift
# 480       rain  13.000000  13.000000  Default  30.0000  30.0000
# 1368      nets   7.000000   7.000000  Default  29.0000  29.0000
# 229      space  17.000000  17.000000  Default  28.0000  28.0000
# 1482   spatial   8.000000   8.000000  Default  27.0000  27.0000
# 470    network  21.000000  21.000000  Default  26.0000  26.0000
# ...        ...        ...        ...      ...      ...      ...
# 175     models   4.525072  16.848766   Topic6  -5.7595   0.0464
# 111      paper   4.242319  11.099787   Topic6  -5.8240   0.3993
# 235       used   4.160356  14.737502   Topic6  -5.8435   0.0963
# 903   learning   4.038914  14.415075   Topic6  -5.8731   0.0888
# 833    support   4.038617  12.462948   Topic6  -5.8732   0.2342
#
# [379 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 1328      1  0.228055    achieves
# 1328      6  0.684166    achieves
# 648       5  0.673490    advanced
# 516       5  0.673466      airpal
# 193       1  0.255652  algorithms
# ...     ...       ...         ...
# 641       2  0.208080     written
# 641       3  0.104040     written
# 641       4  0.104040     written
# 641       6  0.624240     written
# 135       3  0.517473        xiao
#
# [649 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 2, 3, 4, 5, 6])

# %%
import pyLDAvis.gensim
import pickle 
import pyLDAvis

# Visualize the topics
pyLDAvis.enable_notebook()

LDAvis_prepared = pyLDAvis.gensim.prepare(lda_model_2, corpus_tfidf, dictionary,sort_topics=False)
LDAvis_prepared
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.001475  0.006949       1        1  15.877120
# 1     -0.018281 -0.005669       2        1  24.526455
# 2      0.001192  0.007293       3        1  19.665977
# 3      0.004918  0.005347       4        1  17.632759
# 4      0.010695 -0.013920       5        1  22.297686, topic_info=               Term      Freq     Total Category  logprob  loglift
# 480            rain  0.000000  0.000000  Default  30.0000  30.0000
# 339         jupyter  0.000000  0.000000  Default  29.0000  29.0000
# 553          binary  0.000000  0.000000  Default  28.0000  28.0000
# 227      resolution  0.000000  0.000000  Default  27.0000  27.0000
# 1761         mapnik  0.000000  0.000000  Default  26.0000  26.0000
# ...             ...       ...       ...      ...      ...      ...
# 587        research  0.154733  0.425443   Topic5  -6.6901   0.4893
# 174           model  0.148132  0.386067   Topic5  -6.7337   0.5428
# 213   visualization  0.169218  0.565735   Topic5  -6.6006   0.2937
# 113        platform  0.138399  0.343651   Topic5  -6.8016   0.5912
# 235            used  0.138866  0.352421   Topic5  -6.7982   0.5694
#
# [249 rows x 6 columns], token_table=Empty DataFrame
# Columns: [Topic, Freq, Term]
# Index: [], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 2, 3, 4, 5])

# %%
for a,b in bow_corpus[0]:
    print(dictionary[a])
# Out:
# body
# detect
# facial
# first
# foot
# hand
# human
# images
# jointly
# keypoints
# multi
# openpose
# person
# real
# represents
# single
# system
# time
# total

# %%
text = 'this is a visualization software used to create charts'

# %%
preprocess(text)
# Out:
# ['visualization', 'software', 'used', 'create', 'charts']

# %%
bow_vector = dictionary.doc2bow(preprocess(text))
for index, score in sorted(lda_model_2[bow_vector][0], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {},{}".format(score,index+1, lda_model_2.print_topic(index,30)))
# Out:
# Score: 0.9469016194343567	 Topic: 6,0.002*"network" + 0.002*"pytorch" + 0.002*"tile" + 0.002*"html" + 0.002*"interactive" + 0.002*"charts" + 0.002*"pose" + 0.002*"scikit" + 0.002*"tensorflow" + 0.001*"eccv" + 0.001*"method" + 0.001*"ruby" + 0.001*"wrapper" + 0.001*"tetgen" + 0.001*"parameter" + 0.001*"neural" + 0.001*"tensor" + 0.001*"wells" + 0.001*"lithology" + 0.001*"give" + 0.001*"pressure" + 0.001*"vega" + 0.001*"module" + 0.001*"regression" + 0.001*"numpy" + 0.001*"integral" + 0.001*"presented" + 0.001*"renderer" + 0.001*"fast" + 0.001*"able"
# Score: 0.0122231999412179	 Topic: 2,0.002*"learning" + 0.002*"detection" + 0.002*"languages" + 0.002*"object" + 0.002*"jupyter" + 0.001*"framework" + 0.001*"powerful" + 0.001*"ready" + 0.001*"including" + 0.001*"segyio" + 0.001*"library" + 0.001*"research" + 0.001*"intuitive" + 0.001*"feature" + 0.001*"reinforcement" + 0.001*"accurate" + 0.001*"modern" + 0.001*"features" + 0.001*"biomedical" + 0.001*"mapshaper" + 0.001*"neural" + 0.001*"sonnet" + 0.001*"sleek" + 0.001*"front" + 0.001*"supported" + 0.001*"objects" + 0.001*"interactive" + 0.001*"layers" + 0.001*"deep" + 0.001*"bridge"
# Score: 0.011061301454901695	 Topic: 4,0.002*"gdal" + 0.002*"binary" + 0.002*"react" + 0.001*"files" + 0.001*"matrix" + 0.001*"resolution" + 0.001*"robot" + 0.001*"cable" + 0.001*"space" + 0.001*"versions" + 0.001*"frequency" + 0.001*"help" + 0.001*"blog" + 0.001*"image" + 0.001*"input" + 0.001*"geos" + 0.001*"branch" + 0.001*"well" + 0.001*"operators" + 0.001*"meshfix" + 0.001*"densepose" + 0.001*"package" + 0.001*"ansys" + 0.001*"conversion" + 0.001*"eventhub" + 0.001*"human" + 0.001*"packages" + 0.001*"products" + 0.001*"website" + 0.001*"shapely"
# Score: 0.010633249767124653	 Topic: 1,0.002*"spatial" + 0.002*"image" + 0.002*"network" + 0.002*"gitbucket" + 0.002*"scene" + 0.002*"scikit" + 0.002*"nets" + 0.001*"images" + 0.001*"keypoints" + 0.001*"density" + 0.001*"hardware" + 0.001*"super" + 0.001*"project" + 0.001*"processing" + 0.001*"atlases" + 0.001*"neural" + 0.001*"geos" + 0.001*"root" + 0.001*"latent" + 0.001*"neoj" + 0.001*"bolt" + 0.001*"tinkerpop" + 0.001*"magenta" + 0.001*"objects" + 0.001*"resolution" + 0.001*"allows" + 0.001*"known" + 0.001*"laplacian" + 0.001*"domain" + 0.001*"detection"
# Score: 0.00961519218981266	 Topic: 5,0.002*"mapnik" + 0.002*"hyvr" + 0.002*"queries" + 0.001*"tiles" + 0.001*"storage" + 0.001*"support" + 0.001*"classical" + 0.001*"open" + 0.001*"visualization" + 0.001*"transformations" + 0.001*"geological" + 0.001*"useable" + 0.001*"mining" + 0.001*"providing" + 0.001*"highly" + 0.001*"specification" + 0.001*"results" + 0.001*"server" + 0.001*"addresses" + 0.001*"kamb" + 0.001*"airpal" + 0.001*"query" + 0.001*"resnext" + 0.001*"models" + 0.001*"pytext" + 0.001*"structures" + 0.001*"lakefs" + 0.001*"interface" + 0.001*"geojson" + 0.001*"cltk"
# Score: 0.009565453045070171	 Topic: 3,0.002*"average" + 0.002*"pyro" + 0.002*"reduxperformant" + 0.001*"video" + 0.001*"visualization" + 0.001*"pytorch" + 0.001*"fiona" + 0.001*"chrome" + 0.001*"translation" + 0.001*"radar" + 0.001*"flexible" + 0.001*"bindings" + 0.001*"react" + 0.001*"plotting" + 0.001*"penetrating" + 0.001*"chromium" + 0.001*"puppeteer" + 0.001*"headless" + 0.001*"facebook" + 0.001*"source" + 0.001*"scraper" + 0.001*"ground" + 0.001*"nextflow" + 0.001*"open" + 0.001*"basemap" + 0.001*"mplleaflet" + 0.001*"software" + 0.001*"high" + 0.001*"stimulation" + 0.001*"peak"

# %%
lda_model_1[bow_vector][0]
# Out:
# [(0, 0.02954516),
#  (1, 0.027289057),
#  (2, 0.8594328),
#  (3, 0.023520524),
#  (4, 0.024428165),
#  (5, 0.0357843)]

# %%
for a,b in bow_vector:
    print(dictionary[a])
# Out:
# software
# learning
# machine

# %%
lda_model_1.get_document_topics(corpus_tfidif[0])
# Out:
# [(0, 0.0087373005),
#  (1, 0.008933453),
#  (2, 0.0071617523),
#  (3, 0.9599697),
#  (4, 0.0068779592),
#  (5, 0.008319867)]

# %%
for a,b in corpus_tfidif[0]:
    print(dictionary[a])
# Out:
# body
# detect
# facial
# first
# foot
# hand
# human
# images
# jointly
# keypoints
# multi
# openpose
# person
# real
# represents
# single
# system
# time
# total

# %%
df['excerpt'][0]
# Out:
# 'openpose represents the first real-time multi-person system to jointly detect human body hand facial and foot keypoints (in total  keypoints) on single images'

# %%
for t in topics:
    print(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-8ebe9a539ce6> in <module>
# ----> 1 for t in topics:
#       2     print(t)
#
# NameError: name 'topics' is not defined

# %%
topics =lda_model_2.print_topics(-1,30)

# %%
for t in topics:
    print(t[0],t[1])
# Out:
# 0 0.002*"average" + 0.002*"resolution" + 0.001*"presented" + 0.001*"residual" + 0.001*"objects" + 0.001*"coordinate" + 0.001*"shapely" + 0.001*"latent" + 0.001*"training" + 0.001*"paper" + 0.001*"implementation" + 0.001*"repository" + 0.001*"geos" + 0.001*"bolt" + 0.001*"neoj" + 0.001*"tinkerpop" + 0.001*"project" + 0.001*"magenta" + 0.001*"fully" + 0.001*"models" + 0.001*"tested" + 0.001*"simplifies" + 0.001*"algorithms" + 0.001*"nextflow" + 0.001*"fastaifastai" + 0.001*"practices" + 0.001*"welcome" + 0.001*"pose" + 0.001*"eccv" + 0.001*"packages"
# 1 0.003*"scikit" + 0.002*"image" + 0.002*"ready" + 0.002*"html" + 0.002*"interactive" + 0.002*"charts" + 0.002*"languages" + 0.002*"supported" + 0.002*"matrix" + 0.001*"network" + 0.001*"numpy" + 0.001*"tensor" + 0.001*"learning" + 0.001*"domain" + 0.001*"processing" + 0.001*"robot" + 0.001*"cable" + 0.001*"storage" + 0.001*"vega" + 0.001*"blog" + 0.001*"help" + 0.001*"wrapper" + 0.001*"fast" + 0.001*"tensorflow" + 0.001*"debugging" + 0.001*"microsoft" + 0.001*"tensorwatch" + 0.001*"operators" + 0.001*"object" + 0.001*"pytorch"
# 2 0.002*"scene" + 0.002*"rain" + 0.002*"jupyter" + 0.002*"nets" + 0.001*"visualization" + 0.001*"maps" + 0.001*"binary" + 0.001*"intuitive" + 0.001*"powerful" + 0.001*"radar" + 0.001*"biomedical" + 0.001*"mapshaper" + 0.001*"graph" + 0.001*"atlases" + 0.001*"front" + 0.001*"sleek" + 0.001*"software" + 0.001*"geos" + 0.001*"penetrating" + 0.001*"interactive" + 0.001*"bridge" + 0.001*"images" + 0.001*"processing" + 0.001*"contains" + 0.001*"open" + 0.001*"editing" + 0.001*"objects" + 0.001*"ansys" + 0.001*"easier" + 0.001*"known"
# 3 0.002*"spatial" + 0.002*"gdal" + 0.002*"hyvr" + 0.001*"reduxperformant" + 0.001*"level" + 0.001*"keypoints" + 0.001*"regression" + 0.001*"fiona" + 0.001*"hardware" + 0.001*"space" + 0.001*"runs" + 0.001*"bindings" + 0.001*"react" + 0.001*"plotting" + 0.001*"frequency" + 0.001*"integral" + 0.001*"chromium" + 0.001*"headless" + 0.001*"puppeteer" + 0.001*"rendering" + 0.001*"library" + 0.001*"branch" + 0.001*"files" + 0.001*"blocking" + 0.001*"time" + 0.001*"flexible" + 0.001*"provides" + 0.001*"official" + 0.001*"chrome" + 0.001*"port"
# 4 0.002*"detection" + 0.002*"visualization" + 0.002*"gitbucket" + 0.002*"object" + 0.001*"human" + 0.001*"queries" + 0.001*"mesh" + 0.001*"tetgen" + 0.001*"parameter" + 0.001*"powered" + 0.001*"learning" + 0.001*"pyvista" + 0.001*"software" + 0.001*"open" + 0.001*"structures" + 0.001*"densepose" + 0.001*"pressure" + 0.001*"kitware" + 0.001*"research" + 0.001*"sonnet" + 0.001*"framework" + 0.001*"root" + 0.001*"detectron" + 0.001*"provide" + 0.001*"package" + 0.001*"networks" + 0.001*"environment" + 0.001*"tools" + 0.001*"within" + 0.001*"library"
# 5 0.002*"network" + 0.002*"tile" + 0.002*"mapnik" + 0.002*"renderer" + 0.002*"pyro" + 0.001*"react" + 0.001*"files" + 0.001*"neural" + 0.001*"logs" + 0.001*"ruby" + 0.001*"video" + 0.001*"pytorch" + 0.001*"segyio" + 0.001*"density" + 0.001*"resolution" + 0.001*"stratigraphic" + 0.001*"lithology" + 0.001*"wells" + 0.001*"facebook" + 0.001*"translation" + 0.001*"super" + 0.001*"rain" + 0.001*"classical" + 0.001*"image" + 0.001*"connected" + 0.001*"outcrop" + 0.001*"transmission" + 0.001*"render" + 0.001*"pyramid" + 0.001*"application"
